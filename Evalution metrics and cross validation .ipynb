# %%
# Evaluation metrics using sklearn

# ------- confusion metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(label, predicted_label)

# Problem plotting CM of a multilabel classifiction problem
# check -- sklearn.metrics.multilabel_confusion_matrix




# ------- Cross validation under considerations
import keras

from keras.wrapper.scikit_learn import kerasClassifier
from sklearn.model_selection import cross_val_score

def build_classifier():
#     input cnn architecture

# or 
from sklearn.model_selection import KFold






# ---------------------------------------

# sklearn.metrics.classification_report
# return
# {'label 1': {'precision':0.5,
#              'recall':1.0,
#              'f1-score':0.67,
#              'support':1},
#  'label 2': { ... },
#   ...
# }



# ------- specificity
# you can get specificity from the cm
# from sklearn.metrics import confusion_matrix
# y_true = [0, 0, 0, 1, 1, 1, 1, 1]
# y_pred = [0, 1, 0, 1, 0, 1, 0, 1]
# tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
# specificity = tn / (tn+fp)






# -------- sensitivity
# check >>>>> https://gist.github.com/romainmartinez/d1aa798896d2f8cde62e40a3e59ec4a5







# -------- AUC
# sklearn.metrics.roc_auc_score
# sklearn.metrics.roc_auc_score(y_true, y_score, average='macro', sample_weight=None, max_fpr=None, multi_class='raise', labels=None)
# usage: from sklearn.metrics import roc_auc_score






# -------- f1
# >>> from sklearn.metrics import classification_report
# >>> y_true = [0, 1, 2, 2, 2]
# >>> y_pred = [0, 0, 2, 2, 1]
# >>> target_names = ['class 0', 'class 1', 'class 2']
# >>> print(classification_report(y_true, y_pred, target_names=target_names))
#               precision    recall  f1-score   support


# ------
# logging SOLVED
# model.history CHECKING
